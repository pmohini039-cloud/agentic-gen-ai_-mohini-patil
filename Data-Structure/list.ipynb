# %% [markdown]
# List

# %%
l1=[]
l1
# Out:
# []

# %%
l1=[10,20,30,40]     #list of integer datatype
l1
# Out:
# [10, 20, 30, 40]

# %%
l2=['Mohini','Payal','Jyoti','Ketan','Om']  #list of String datatype
l2
# Out:
# ['Mohini', 'Payal', 'Jyoti', 'Ketan', 'Om']

# %%
l3=[10.2,6.3,9.4]      #list of float datatype
l3
# Out:
# [10.2, 6.3, 9.4]

# %%
l4=[10,10.3,'Mayuri']    #List of mixed datatype
l4
# Out:
# [10, 10.3, 'Mayuri']

# %%
l5=[10,9.5,[60,'Mohini'],[9,'Neha']]     #nested list
l5
# Out:
# [10, 9.5, [60, 'Mohini'], [9, 'Neha']]

# %%
print(type(l1))
# Out:
# <class 'list'>

# %%
len(l4)      #length of list
# Out:
# 3

# %% [markdown]
# list_indexing

# %%
l3[0]    #retrives first element of the list
# Out:
# 10.2

# %%
l2[0][0]    #nested indexing access the 1st character of the 1st list element
# Out:
# 'M'

# %%
l4[-1]    #retrives the last element of the list
# Out:
# 'Mayuri'

# %% [markdown]
# list_slicing

# %%
l=['neha','mahesh','mohini','nayna','jayesh','bhavesh','divya','shreyas']
l
# Out:
# ['neha', 'mahesh', 'mohini', 'nayna', 'jayesh', 'bhavesh', 'divya', 'shreyas']

# %%
l[0:3]    #returns all items from 0 to 3rd index location excluding the all other items
# Out:
# ['neha', 'mahesh', 'mohini']

# %%
l[2:6]
# Out:
# ['mohini', 'nayna', 'jayesh', 'bhavesh']

# %%
l[:3]         #return first 3 items
# Out:
# ['neha', 'mahesh', 'mohini']

# %%
l[-3]   #returns last 3rd item
# Out:
# 'bhavesh'

# %%
l[-1:]   #returns last item
# Out:
# ['shreyas']

# %%
l[:]     #returns whole list
# Out:
# ['neha', 'mahesh', 'mohini', 'nayna', 'jayesh', 'bhavesh', 'divya', 'shreyas']

# %% [markdown]
# add,remove_and_change_items

# %%
l=['neha','mahesh','mohini','nayna','jayesh','bhavesh','divya','shreyas']
l
# Out:
# ['neha', 'mahesh', 'mohini', 'nayna', 'jayesh', 'bhavesh', 'divya', 'shreyas']

# %%
l.append('panu')    #add an item to the last of the list
l
# Out:
# ['neha',
#  'mahesh',
#  'mohini',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'panu']

# %%
l.insert(9,'dakshu')   #add an item at the location index 9
l
# Out:
# ['neha',
#  'mahesh',
#  'mohini',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'panu',
#  'dakshu']

# %%
l.remove('mohini')
l
# Out:
# ['neha',
#  'mahesh',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'panu',
#  'dakshu']

# %%
l.pop()    #removes the last item of the list
l
# Out:
# ['neha', 'mahesh', 'nayna', 'jayesh', 'bhavesh', 'divya', 'shreyas', 'panu']

# %%
l.pop(6)   #remove an item at index location 3
l
# Out:
# ['neha', 'mahesh', 'nayna', 'jayesh', 'bhavesh', 'divya', 'panu']

# %%
del l[6]    #delete item at index location 6
l
# Out:
# ['neha', 'mahesh', 'nayna', 'jayesh', 'bhavesh', 'divya']

# %%
l[0] = 1
l[1] = 14
l[2] = 11
l[3] = 5
print(l)
# Out:
# [1, 14, 11, 5, 'bhavesh', 'divya']

# %%
l.clear()     #empty list or delete all items of the list
l
# Out:
# []

# %%
del l     #delete the whole list
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 del l
# ----> 2 l
#
# NameError: name 'l' is not defined

# %% [markdown]
# copy_list

# %%
l2=['Mohini','Payal','Jyoti','Ketan','Om']  #list of String datatype
l2
# Out:
# ['Mohini', 'Payal', 'Jyoti', 'Ketan', 'Om']

# %%
mylist=l2    #create the reference mylist

# %%
id(mylist), id(l2)    #the address of both the list will be same
# Out:
# (3125745472640, 3125745472640)

# %%
l2=mylist.copy()    #create a copy of the list

# %%
id(l2)
# Out:
# 3125745584064

# %%
mylist[0]
# Out:
# 'Mohini'

# %%
mylist
# Out:
# ['Mohini', 'Payal', 'Jyoti', 'Ketan', 'Om']

# %% [markdown]
# join_list

# %%
l=['neha','mahesh','mohini','nayna','jayesh','bhavesh','divya','shreyas']
l2=['Mohini','Payal','Jyoti','Ketan','Om']

# %%
l3=l+l2     #join two list by + operator
print(l3)
# Out:
# ['neha', 'mahesh', 'mohini', 'nayna', 'jayesh', 'bhavesh', 'divya', 'shreyas', 'Mohini', 'Payal', 'Jyoti', 'Ketan', 'Om']

# %%
l.extend(l2)     #append l2 to with l
l
# Out:
# ['neha',
#  'mahesh',
#  'mohini',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'Mohini',
#  'Payal',
#  'Jyoti',
#  'Ketan',
#  'Om']

# %% [markdown]
# list_membersip

# %%
l
# Out:
# ['neha',
#  'mahesh',
#  'mohini',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'Mohini',
#  'Payal',
#  'Jyoti',
#  'Ketan',
#  'Om']

# %%
'mohini' in l   #check if mohini exist in the list
# Out:
# True

# %%
'mayuri' in l
# Out:
# False

# %%
if 'mahesh' in l:
    print('mahesh is present')
else:
    print('mahesh is not present')
# Out:
# mahesh is present

# %% [markdown]
# reverse_and_sort_list

# %%
l
# Out:
# ['neha',
#  'mahesh',
#  'mohini',
#  'nayna',
#  'jayesh',
#  'bhavesh',
#  'divya',
#  'shreyas',
#  'Mohini',
#  'Payal',
#  'Jyoti',
#  'Ketan',
#  'Om']

# %%
l.reverse()   #reverse the list
l
# Out:
# ['Om',
#  'Ketan',
#  'Jyoti',
#  'Payal',
#  'Mohini',
#  'shreyas',
#  'divya',
#  'bhavesh',
#  'jayesh',
#  'nayna',
#  'mohini',
#  'mahesh',
#  'neha']

# %%
l=l[:-1]   #reverse the list
l
# Out:
# ['Om',
#  'Ketan',
#  'Jyoti',
#  'Payal',
#  'Mohini',
#  'shreyas',
#  'divya',
#  'bhavesh',
#  'jayesh',
#  'nayna',
#  'mohini',
#  'mahesh']

# %%
mylist=[10,9,1,3,5,7,3,5,6]     #sort list in ascending order
mylist.sort()
mylist
# Out:
# [1, 3, 3, 5, 5, 6, 7, 9, 10]

# %%
mylist.sort(reverse=True)     #sort list in descending order
mylist
# Out:
# [10, 9, 7, 6, 5, 5, 3, 3, 1]

# %%
myl=[20,90,3,4,5,70]    #returns a new sorted list and doesn't change the original list
sorted(myl)
myl
# Out:
# [20, 90, 3, 4, 5, 70]

# %% [markdown]
# loop_through_list

# %%
l
# Out:
# ['Om',
#  'Ketan',
#  'Jyoti',
#  'Payal',
#  'Mohini',
#  'shreyas',
#  'divya',
#  'bhavesh',
#  'jayesh',
#  'nayna',
#  'mohini',
#  'mahesh']

# %%
for i in l:
    print(i)
# Out:
# Om
# Ketan
# Jyoti
# Payal
# Mohini
# shreyas
# divya
# bhavesh
# jayesh
# nayna
# mohini
# mahesh

# %%
for i in enumerate(l):
     print(i)
# Out:
# (0, 'Om')
# (1, 'Ketan')
# (2, 'Jyoti')
# (3, 'Payal')
# (4, 'Mohini')
# (5, 'shreyas')
# (6, 'divya')
# (7, 'bhavesh')
# (8, 'jayesh')
# (9, 'nayna')
# (10, 'mohini')
# (11, 'mahesh')

# %% [markdown]
# count

# %%
list9=['one','two','three','four','one','three','nine','one']
list9
# Out:
# ['one', 'two', 'three', 'four', 'one', 'three', 'nine', 'one']

# %%
list9.count('one')   #number of time item one occured in the list
# Out:
# 3

# %% [markdown]
# all/any

# %%
l1=[1,2,3,4,5,0]
l1
# Out:
# [1, 2, 3, 4, 5, 0]

# %%
all(l1)   #will return false as one value is false (value 0)
# Out:
# False

# %%
any(l1)   #will return true as items in the list are true value
# Out:
# True
