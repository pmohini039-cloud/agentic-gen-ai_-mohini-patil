# %% [markdown]
# python conditional statement

# %%
i=10                                    #if statement
if (i>15):
    print("10 is less than 15")
print("i'm mot in if")
# Out:
# i'm mot in if

# %%
i=10       #if statement
if i < 15:
    print("i is less than 15")
# Out:
# i is less than 15

# %%
#check if number is even or odd
i= int(input("Enter a number:"))                      
if (i%2==0):
    print("even number")
else:
    print("odd number")
# Out:
# Enter a number: 6
# even number

# %%
#check if person is elegeble to vote or not
age=int(input("Enter a age:"))
if (age>=18):
    print("Elegeble to vote")
else:
    print("Not elegeble to vote")
# Out:
# Enter a age: 21
# Elegeble to vote

# %%
#check if the year is leap or not
year=int(input("Enter a year:"))
if (year % 4 == 0):
    print("leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year: 2014
# Not a leap year

# %%
def digitsum(n):             #if else using list coprehension
    dsum=0
    for ele in str(n):
        dsum+=int(ele)
    return dsum
l=[365,111,562,945,6726,873]
newlist=[digitsum(i) for i in l if i & 1]
print(newlist)
# Out:
# [14, 3, 18, 18]

# %%
i=10                     #nested if statement
if(i==10):
    if(i<15):
        print("i is smaller than 15")
    if(i<12):
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
i=25                    #if-elif-else ladder
if(1==10):
    print("i is 10")
elif(i==15):
    print("i is 15")
elif(i==20):
    print("i is 20")
else:
    print("i is not present")
# Out:
# i is not present

# %%
#check if the number is positive, negative or zero
num=int(input("Enter a number:"))
if (num < 0):
    print("negative")
elif (num  > 0):
    print("Positive")
else:
    print("zero")
# Out:
# Enter a number: -10
# negative

# %%
# find the greatest of two numbers
a=int(input("Enter the 1st number:"))
b=int(input("Enter the 2nd number:"))
if (a > b):
    print("Greatest:",a)
else:
    print("Greatest:",b)
# Out:
# Enter the 1st number: 7
# Enter the 2nd number: 3
# Greatest: 7

# %%
#check if the number is multiple of 5
num=int(input("Enter a number"))
if (num % 5 == 0):
    print("Multiple of 5")
else:
    print("not multiple of 5")
# Out:
# Enter a number 65
# Multiple of 5

# %%
#check if the character is vowel or consonant
char=input("Enter a Character:").lower()
if char in 'aeiou':
    print("vowel")
else:
    print("consonant")
# Out:
# Enter a Character: w
# consonant

# %%
#check if the person is eligible for senior citizen discount
age=int(input("Enter your age"))
if (age >= 60):
    print("you are eligible for senior citizen discount")
else:
    print("You are not eligible")
# Out:
# Enter your age 78
# you are eligible for senior citizen discount

# %%
#check if the number is single digit number
num=int(input("Enter a number:"))
if ( 0 <= abs (num) < 10):            #here abs() makesure that the negative number treated like positive one
    print("single digit number")
else:
    print("not a single digit number")
# Out:
# Enter a number: 6
# single digit number

# %%
#print "Good Morning" if the time is before 12 otherwise print "Good Afternoon"
hour=int(input("Enter hour (24 hour format):"))
if (hour < 12):
    print("Good Morning")
else:
    print("Good Afternoon")
# Out:
# Enter hour (24 hour format): 7
# Good Morning

# %%
#check if the string is empty or not
s=input("Enter your string")
if not s:
    print("String is emty")
else:
    print("String is not empty")
# Out:
# Enter your string Mohini
# String is not empty

# %%
#verify if a number is perfect square
import math
num=int(input("Enter a number:"))
if (math.isqrt(num)**2==num):
    print("perfect square")
else:
    print("not a perfect square")
# Out:
# Enter a number: 4
# perfect square

# %%
#determine if the number is between 1 to 100
num=int(input("Enter a Number:"))
if ( 1 <= num <= 100):
    print("within range")
else:
    print("out of range")
# Out:
# Enter a Number: 90
# within range

# %%
#print weekend if the day is saturday, sunday otherwise print weekday
day=input("Enter a day:").lower()
if (day in ['saturday', 'sunday']):
    print("weekend")
else:
    print("weekday")
# Out:
# Enter a day: monday
# weekday

# %%
#find the given number exactly divisible by both 3 and 7
num=int(input("Enter a number:"))
if (num % 3== 0 and num % 7 == 0):
    print("divisible by both")
else:
    print("not divisible by 3 and 7")
# Out:
# Enter a number: 8
# not divisible by 3 and 7

# %%
#check if the sum of two numbers is greater than 100
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
if (a+b) > 100:
    print("sum is greater than 100")
else:
    print("sum is not greater than 100")
# Out:
# Enter first number: 90
# Enter second number: 5
# sum is not greater than 100

# %%
#write a program to find the minimum of 2 numbers
a=int(input("Enter a 1st number:"))
b=int(input("Enter a 2nd number:"))
if ( a < b):
    print("Minimum:",a)
else:
    print("Minimum:",b)
# Out:
# Enter a 1st number: 76
# Enter a 2nd number: 56
# Minimum: 56

# %%
#check if the number is divisible by 2 but not by 3
num=int(input("Enter a number:"))
if (num % 2 == 0 and num % 3 != 0):
    print("Divisible by 2 not by 3")
else:
    print("Does not meet criteria")
# Out:
# Enter a number: 4
# Divisible by 2 not by 3

# %%
#determine if the given alphabate is uppercase or lowercase
char=input("Enter an alphabate:")
if (char.isupper()):
    print("UpperCase")
else:
    print("Lowercase")
# Out:
# Enter an alphabate: e
# Lowercase

# %%
#check if triangle is valid given 3 side lengths
a=int(input("Enter first side:"))
b=int(input("Enter second side:"))
c=int(input("Enter third side:"))
if ( a+b>c and a+c>b and b+c>a ):
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first side: 4
# Enter second side: 6
# Enter third side: 8
# Valid Triangle

# %%
#find the largest of the three numbers
a=int(input("Enter a first number:"))
b=int(input("Enter a second number:"))
c=int(input("Enter a third number:"))
if (a >= b and a >= c):
    print("largest:",a)
elif (b >= a and b >= c):
    print("largest:",b)
else:
    print("largest:",c)
# Out:
# Enter a first number: 6
# Enter a second number: 5
# Enter a third number: 4
# largest: 6

# %%
#determine if a number is prime number
num=(int(input("Enter a number:")))
if (num > 1):
     for i in range(2, int(num**0.5)+1):
       if ( num % i == 0):
            print("not a prime number")
            break
       else:
           print("prime number:")
else:
    print("Not a prime number:")
# Out:
# Enter a number: 6
# not a prime number

# %%
#check if the person is elegible for driving license
age=int(input("Enter age:"))
passed_test=input("Did you passed your driving test? (yes/no):").lower()
if (age >= 18 and passed_test == "yes"):
    print("you are eligible:")
else:
    print("you are not eligible:")
# Out:
# Enter age: 20
# Did you passed your driving test? (yes/no): yes
# you are eligible:

# %%
#determine if the triangle is  equilateral, isosceles, or scalene
a=int(input("Enter first side:"))
b=int(input("Enter second side:"))
c=int(input("Enter third side:"))
if (a==b==c):
    print("Triangle is equilateral:")
elif (a==b or b==c or c==a):
    print("Triangle is isosceles:")
else:
    print("Triangle is scalene:")
# Out:
# Enter first side: 7
# Enter second side: 9
# Enter third side: 0
# Triangle is scalene:

# %%
#determine if the student pass or fails
marks=int(input("Enter your Marks:"))
if (marks >= 40):
    print("pass")
else:
    print("fail")
# Out:
# Enter your Marks: 50
# pass

# %%
#check if the number is palindrome
num=input("Enter a number:")
if  num==num[::-1]:
    print("Number is palindrome")
else:
    print("Number is not palindrome")
# Out:
# Enter a number: 543
# Number is not palindrome

# %%
#calculate the electricity bill
units = int(input("Enter electricity unit consumed:"))
if ( units <= 100 ):
    bill = units*5
elif ( units <= 300 ):
    bill = ( 100 * 5 ) + ( units - 100 ) * 10
else:
    bill = ( 100 * 5 ) + ( 200 * 10 ) + ( units - 300 ) * 15
print("Total Bill: ₹",bill)
# Out:
# Enter electricity unit consumed: 50
# Total Bill: ₹ 250

# %%
#find the grade of the students
marks=int(input("Enter Marks:"))
if (marks >= 90):
    print("Grade A:")
elif (marks >= 80):
    print("Grade B:")
elif (marks >= 70):
    print("Grade C:")
elif (marks >= 60):
    print("Grade D:")
elif (marks >= 40):
    print("Grade E:")
else:
    print("Fail")
# Out:
# Enter Marks: 95
# Grade A:

# %%
#determine if the given date is valid
import calendar
day=int(input("Enter a day:"))
month=int(input("Enter a month:"))
year=int(input("Enter a year:"))
if 1 <= month and 1 <= 12 and 1 <= day <= calendar.monthrange(year,month)[1]:
    print("valid date:")
else:
    print("invalid date:")
# Out:
# Enter a day: 30
# Enter a month: 2
# Enter a year: 2026
# invalid date:

# %%
#check if given time is AM or PM
hour=int(input("Enter hour ( 24 hour format):"))
if (hour < 12):
    print("AM")
else:
    print("PM")
# Out:
# Enter hour ( 24 hour format): 11
# AM

# %%
#check if the number is Armstrong 
num = int(input("Enter a Number:"))
power = len(str(num))

if sum(int(digit)**power for digit in str(num)) == num:
    print("Armstrong Number")
else:
    print("Not an Armstrong Number")
# Out:
# Enter a Number: 123
# Not an Armstrong Number

# %%
#determine the type of quadrilateral
a=int(input("Enter a 1st side"))
b=int(input("Enter a 2nd side"))
c=int(input("Enter a 3nd side"))
d=int(input("Enter a 4nd side"))
if (a==b==c==d):
    print("square")
elif (a==c and b==d):
    print("Rectange")
else:
    print("other quadrilateral")
# Out:
# Enter a 1st side 8
# Enter a 2nd side 6
# Enter a 3nd side 8
# Enter a 4nd side 4
# other quadrilateral

# %%
#implement the basic calculator
a=float(input("Enter 1st number"))
b=float(input("Enter 2nd number"))
op=input("Enter Operation (+,-,*,/):")
if (op=="+"):
    print(a+b)
elif (op=="-"):
    print(a-b)
elif (op=="*"):
    print(a*b)
elif (op=="/"):
    print(a/b)
else:
    print("invalid operator")
# Out:
# Enter 1st number 5
# Enter 2nd number 3
# Enter Operation (+,-,*,/): +
# 8.0

# %%
#check if the bank balance is sufficiant for withdrowal
balance=float(input("Enter Account Balanace"))
withdraw=float(input("Enter Withdrowal Ammount"))
if (balance >= withdraw):
    print("withdrawal successful")
else:
    print("insufficiant funds")
# Out:
# Enter Account Balanace 2000
# Enter Withdrowal Ammount 1000
# withdrawal successful

# %%
#implement a temperature converter
temp=float(input("Enter temperature"))
unit=input("Enter unit (C/F):").upper()
if unit=="C":
    print("Fahrenheit:",(temp*9/5)+32)
elif unit=="F":
    print("Celcius:",(temp-32)*5/9)
else:
    print("invalid unit")
# Out:
# Enter temperature 45
# Enter unit (C/F): C
# Fahrenheit: 113.0

# %%
#check if number lies whithin range (50-100)
num=int(input("Enter Number:"))
if (50 <= num <= 100):
    print("within range")
else:
    print("outof range")
# Out:
# Enter Number: 101
# outof range

# %%
#determine if year is century year
year=int(input("Enter a year:"))
if (year % 100==0):
    print("century year")
else:
    print("not century year")
# Out:
# Enter a year: 2026
# not century year

# %%
#check if number is power of two
num=int(input("enter a number"))
if (num > 0 and (num & (num-1))==0):
    print("power of 2")
else:
    print("not power of 2")
# Out:
# enter a number 4
# power of 2

# %%
#determine how many days month has
month=int(input("enter a month (1-12:"))
year=int(input("enter year:"))
days=[31,28+ (1 if (year% 4==0 and year % 100 != 0) or (year % 400==0) else 0), 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
print("Days",days[month-1])
# Out:
# enter a month (1-12: 8
# enter year: 2004
# Days 31

# %%
#validate a password
import re
password=(input("Enter password:"))
if len(password)>=8 and re.search(r"[A-Za-z]",password )and re.search(r"\d",password):
    print("valid password")
else:
    print("invalid password")
# Out:
# Enter password: Mohini@2004
# valid password

# %%
#implement a ticket pricing system
age=int(input("Enter age:"))
if age < 5:
    print("Ticket price :Free")
elif age >= 60:
    print("Ticket price: ₹ 50")
else:
    print("Ticket price: ₹ 100")
# Out:
# Enter age: 22
# Ticket price: ₹ 100

# %%
#check if three numbers form a pythagorean triplet
a,b,c=sorted(map(int,input("Enter three numbers:").split(",")))
if a**2+b**2==c**2:
    print("pythagorean triplet:")
else:
    print("not pythagorean triplet")
# Out:
# Enter three numbers: 4,6,5
# not pythagorean triplet
