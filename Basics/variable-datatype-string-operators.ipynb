# %%
a=5
b=7.5
c='not'
d=9+6j
e=True
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 5
# 7.5
# not
# (9+6j)
# True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
type(c)
# Out:
# str

# %% [markdown]
#                                                               String

# %%
print('Mohini')
# Out:
# Mohini

# %%
"My Name Is Mohini"
# Out:
# 'My Name Is Mohini'

# %%
s1="My Name Is Mohini"
s1
# Out:
# 'My Name Is Mohini'

# %%
a=3
b=8
c=a+b
print(c)
# Out:
# 11

# %%
a=9
b="hii"
print(type(b))
# Out:
# <class 'str'>

# %%
print('My Name Is,"Mohini"')
# Out:
# My Name Is,"Mohini"

# %% [markdown]
#                                          Print Mohini 3 Times

# %%
'Mohini' + 'Mohini' + 'Mohini'
# Out:
# 'MohiniMohiniMohini'

# %%
'Mohini'    'Mohini'
# Out:
# 'MohiniMohini'

# %%
6*' Mohini'    #space between the words
# Out:
# ' Mohini Mohini Mohini Mohini Mohini Mohini'

# %% [markdown]
#                                     Variable||Identifier||Object

# %%
a=5  #here a is variable and 5 is value or datatype
a
# Out:
# 5

# %%
_ + 10
# Out:
# 15

# %% [markdown]
#                                            String Variable

# %%
name='My Name Is'
name
# Out:
# 'My Name Is'

# %%
name+' Mohini'
# Out:
# 'My Name Is Mohini'

# %%
len(name)   #print the length of the word
# Out:
# 10

# %%
name[0]
# Out:
# 'M'

# %%
name[9]
# Out:
# 's'

# %%
name[-9]
# Out:
# 'y'

# %%
name[3]
# Out:
# 'N'

# %% [markdown]
#                                                     Slicing

# %%
name
# Out:
# 'My Name Is'

# %%
name[0:3]   #To print 2 characters
# Out:
# 'My '

# %%
name[4:]
# Out:
# 'ame Is'

# %%
name[:3]
# Out:
# 'My '

# %%
name[3:9]
# Out:
# 'Name I'

# %%
name
# Out:
# 'My Name Is'

# %%
name1='good'
name1
# Out:
# 'good'

# %%
name1[3:6]
# Out:
# 'd'

# %%
name1
# Out:
# 'good'

# %%
name1[1:]
# Out:
# 'ood'

# %%
'd' +name1[1:]
# Out:
# 'dood'

# %%
name1
# Out:
# 'good'

# %% [markdown]
#                                                    Introduction to id

# %%
num=6
id(num)
# Out:
# 140715172340808

# %%
name='Mohini'
id(name)
# Out:
# 3089405944832

# %%
z=60
id(z)
# Out:
# 140715172342536

# %%
z=90       #As we change the value the adress also changes
id(z)
# Out:
# 140715172343496

# %% [markdown]
#                                                       Operators

# %% [markdown]
#                                                   Arithmetic Operators

# %%
a=20
b=30
c=a+b
print(c)
# Out:
# 50

# %%
print(a+b)  #Addition
print(a-b)  #Subtraction
print(a*b)  #Multiplication
print(a/b)  #Float Division
# Out:
# 50
# -10
# 600
# 0.6666666666666666

# %%
5+5*5
# Out:
# 30

# %%
(5+5)*5   #Bodmass
# Out:
# 50

# %%
8+5-3
# Out:
# 10

# %%
8*8*8*8*8
# Out:
# 32768

# %%
15%2   #Modulus
# Out:
# 1

# %% [markdown]
#                                                          Assignment Operator

# %%
m=5
m
# Out:
# 5

# %%
m+2   #it will imcrease the value of m by 2
# Out:
# 7

# %%
m
# Out:
# 5

# %%
m+=2
m
# Out:
# 7

# %%
m-=1
m
# Out:
# 5

# %%
m*=3
m
# Out:
# 15

# %%
m/=6
m
# Out:
# 2.5

# %%
m//=9
m
# Out:
# 0.0

# %%
m,n=9,10   #You can assign variable in one line also
print(m)
print(n)
# Out:
# 9
# 10

# %% [markdown]
#                                                         Unary Operator

# %%
n
# Out:
# 10

# %%
n=(-n)
n
# Out:
# -10

# %%
-n
# Out:
# 10

# %% [markdown]
#                                                     Relational Operator

# %%
a=5
b=6
print(a)
print(b)
# Out:
# 5
# 6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b=5    #Here we will change the valuw of b
b
# Out:
# 5

# %%
a==b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# False

# %% [markdown]
#                                                    Logical Operator

# %%
a=5
b=9
print(a)
print(b)
# Out:
# 5
# 9

# %%
a<8 and b<4
# Out:
# False

# %%
a>8 and b>4
# Out:
# False

# %%
a<8 or b<4
# Out:
# True

# %%
a>8 or b>4
# Out:
# True

# %%
w=False
w
# Out:
# False

# %%
not w
# Out:
# True
